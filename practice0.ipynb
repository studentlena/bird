# %% [markdown]
# <a href="https://colab.research.google.com/github/studentlena/bird/blob/main/practice0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/thesis
# Out:
# /content/drive/MyDrive/thesis

# %%
! git clone https://github.com/studentlena/bird.git
# Out:
# Cloning into 'bird'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 11 (delta 0), reused 11 (delta 0), pack-reused 0
# Unpacking objects: 100% (11/11), done.

# %%
# !sudo apt update &&apt install -y openslide-tools #配置

# %%
! pip install pytest-runner
! pip install librosa

# %%
! pip install pyaudio
! pip install pydub

# %%
# %cd /content/drive/MyDrive/thesis/bird
# Out:
# /content/drive/MyDrive/thesis/bird

# %%
! python "/content/drive/MyDrive/thesis/bird/create_data.py"
# Out:
# Audio：1/4
# Audio：2/4
# Audio：3/4
# Audio：4/4
#   0% 0/397 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0% 1/397 [00:01<11:41,  1.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1% 2/397 [00:05<18:21,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1% 3/397 [00:06<12:34,  1.91s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %% [markdown]
# # 新段落

# %%
import openslide

# %%
#!nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.
